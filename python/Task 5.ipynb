# %%
import numpy as np 
import pandas as pd

# %%
data = {'City': ['  Mumbai', 'Delhi  ', '  Jaipur  ', 'Pune']}
df = pd.DataFrame(data)

# %%
df
# Out:
#          City
# 0      Mumbai
# 1     Delhi
# 2    Jaipur
# 3        Pune

# %%
df['City']=df['City'].str.strip()

# %%
df['City']=df['City'].str.lower()
df['City']
# Out:
# 0    mumbai
# 1     delhi
# 2    jaipur
# 3      pune
# Name: City, dtype: str

# %%
df['City']=df['City'].str.upper()
df['City']
# Out:
# 0    MUMBAI
# 1     DELHI
# 2    JAIPUR
# 3      PUNE
# Name: City, dtype: str

# %%
# 1. Missing Values Handle Karna (dropna & fillna)
# Task: inventory_df mein missing values wali rows drop karni thi, aur doosre case mein missing Stock_Count ko 0 se fill karna tha.

# Missing values wali saari rows hamesha ke liye drop karna
inventory_df.dropna(inplace=True)

# Sirf specific column ke blanks ko 0 se bharna
inventory_df['Stock_Count'] = inventory_df['Stock_Count'].fillna(0)

# 2. String Cleaning (strip())
# Task: Customer_Name ke aage aur peeche ke hidden extra spaces ko hatana.

# Text (string) data clean karne ke liye .str.strip() ka use
customer_df['Customer_Name'] = customer_df['Customer_Name'].str.strip()
